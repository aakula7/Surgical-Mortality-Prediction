# %%
import pandas as pd
import numpy as np
import time

# %%
Q1 = pd.read_csv('2008Q1_Charges.csv', index_col = 0)
Q1.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (3,4,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\python38\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#       RECORD_ID  REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE MODIFIER_1  \
# 0  120080000001         100.0             NaN                  NaN        NaN
# 1  120080000002         100.0             NaN                  NaN        NaN
# 2  120080000003         100.0             NaN                  NaN        NaN
# 3  120080000004         100.0             NaN                  NaN        NaN
# 4  120080000005         100.0             NaN                  NaN        NaN
#
# ...

# %%
Q2 = pd.read_csv('2008Q2_Charges.csv', index_col = 0)
Q2.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (3,4,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\python38\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#       RECORD_ID  REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE MODIFIER_1  \
# 0  120080796114         100.0             NaN                  NaN        NaN
# 1  120080796115         100.0             NaN                  NaN        NaN
# 2  120080796116         100.0             NaN                  NaN        NaN
# 3  120080796117         100.0             NaN                  NaN        NaN
# 4  120080796118         100.0             NaN                  NaN        NaN
#
# ...

# %%
Q3 = pd.read_csv('2008Q3_Charges.csv', index_col = 0)
Q3.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (3,4,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\python38\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#       RECORD_ID  REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE MODIFIER_1  \
# 0  120080798358         121.0             NaN                  NaN        NaN
# 1  120080798358         250.0             NaN                  NaN        NaN
# 2  120080798358         420.0             NaN                  NaN        NaN
# 3  120080798358         430.0             NaN                  NaN        NaN
# 4  220080748435         110.0             NaN                  NaN        NaN
#
# ...

# %%
Q4 = pd.read_csv('2008Q4_Charges.csv', index_col = 0)
Q4.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (3,4,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\python38\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#       RECORD_ID  REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE MODIFIER_1  \
# 0  320080774050         100.0             NaN                  NaN        NaN
# 1  320080774051         100.0             NaN                  NaN        NaN
# 2  320080774052         100.0             NaN                  NaN        NaN
# 3  320080774053         100.0             NaN                  NaN        NaN
# 4  320080774054         100.0             NaN                  NaN        NaN
#
# ...

# %%
Y2008 = pd.concat([Q1, Q2, Q3, Q4], sort = False)
Y2008.head()
# Out:
#       RECORD_ID  REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE MODIFIER_1  \
# 0  120080000001         100.0             NaN                  NaN        NaN
# 1  120080000002         100.0             NaN                  NaN        NaN
# 2  120080000003         100.0             NaN                  NaN        NaN
# 3  120080000004         100.0             NaN                  NaN        NaN
# 4  120080000005         100.0             NaN                  NaN        NaN
#
#   MODIFIER_2  MODIFIER_3  MODIFIER_4 UNIT_MEASUREMENT_CODE  UNITS_OF_SERVICE  \
# 0        NaN         NaN         NaN                    DA              12.0
# 1        NaN         NaN         NaN                    DA              10.0
# 2        NaN         NaN         NaN                    DA               6.0
# 3        NaN         NaN         NaN                    DA              78.0
# 4        NaN         NaN         NaN                    DA              12.0
#
# ...

# %%
Y2008.tail()
# Out:
#              RECORD_ID  REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE  \
# 11271846  420080794372         301.0             NaN                  NaN
# 11271847  420080794372         305.0             NaN                  NaN
# 11271848  420080794372         329.0             NaN                  NaN
# 11271849  420080794372         360.0             NaN                  NaN
# 11271850  420080794372         710.0             NaN                  NaN
#
#          MODIFIER_1 MODIFIER_2  MODIFIER_3  MODIFIER_4 UNIT_MEASUREMENT_CODE  \
# 11271846        NaN        NaN         NaN         NaN                    UN
# 11271847        NaN        NaN         NaN         NaN                    UN
# 11271848        NaN        NaN         NaN         NaN                    UN
# 11271849        NaN        NaN         NaN         NaN                    UN
# 11271850        NaN        NaN         NaN         NaN                    UN
#
# ...

# %%
Y2008.shape
# Out:
# (45097221, 13)

# %%
print(Q1.shape[0] + Q2.shape[0] + Q3.shape[0] + Q4.shape[0])
# Out:
# 45097221

# %%
start = time.time()
Y2008.to_csv('Charges_08.csv')
end = time.time()
print(end - start)
# Out:
# 314.1824824810028
