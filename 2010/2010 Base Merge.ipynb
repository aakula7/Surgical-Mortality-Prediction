# %%
import pandas as pd
import numpy as np
import time

# %%
Q1 = pd.read_csv('2010Q1_Base.csv', index_col = 0)
Q1.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (4,5,6,7,8,9,10,11,15,16,18,19,25,26,27,29,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,95,98,101,102,104,107,108,110,111,113,114,116,117,119,120,122,123,125,128,129,131,132,134,135,137,138,140,141,143,144,146,147,149,150,152,155,156,158,161,162,164,165,167,168,169,170,171,172,173,174,175,178,179,180,181,182,186,187,188,189,190,191,192,193,194,195,196,197,198,200,202,204,206,208,210,211,212,213,214,215,222,224,226,228,230,232,234,236) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   DISCHARGE_QTR  THCIC_ID          PROVIDER_NAME FAC_TEACHING_IND  \
# 0        2010Q1       100  Austin State Hospital              NaN
# 1        2010Q1       100  Austin State Hospital              NaN
# 2        2010Q1       100  Austin State Hospital              NaN
# ...

# %%
Q2 = pd.read_csv('2010Q2_Base.csv', index_col = 0)
Q2.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (4,5,6,7,8,9,10,11,15,16,18,19,24,25,26,29,67,68,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,95,96,98,99,101,102,104,105,107,108,110,111,113,114,116,117,119,120,122,123,125,126,128,129,131,132,134,135,137,138,140,141,143,144,146,147,149,150,152,153,155,156,158,159,161,162,164,165,167,168,169,170,171,172,173,174,175,178,179,180,181,182,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,210,211,212,213,214,215,222,224,226,228,230,232,234,238) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   DISCHARGE_QTR  THCIC_ID          PROVIDER_NAME FAC_TEACHING_IND  \
# 0        2010Q2       100  Austin State Hospital              NaN
# 1        2010Q2       100  Austin State Hospital              NaN
# ...

# %%
Q3 = pd.read_csv('2010Q3_Base.csv', index_col = 0)
Q3.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (4,5,6,7,8,9,10,11,15,16,18,19,24,25,26,27,29,67,68,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,95,96,98,99,101,102,104,105,107,108,110,111,113,114,116,117,119,120,122,123,125,126,128,129,131,132,134,135,137,138,140,141,143,144,146,147,149,150,152,153,155,156,158,159,161,162,164,165,167,168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,186,187,188,189,190,191,192,193,194,195,196,197,198,200,202,204,206,208,210,211,212,213,214,215,222,224,226,228,230,232,234) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   DISCHARGE_QTR  THCIC_ID          PROVIDER_NAME FAC_TEACHING_IND  \
# 0        2010Q3       100  Austin State Hospital              NaN
# 1        2010Q3       100  Austin State Hospital              NaN
# ...

# %%
Q4 = pd.read_csv('2010Q4_Base.csv', index_col = 0)
Q4.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (4,5,6,7,8,9,10,11,16,18,19,24,25,26,27,29,67,68,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,95,98,99,101,102,104,105,107,108,110,111,113,114,116,117,119,120,122,123,125,126,128,129,131,132,134,135,137,138,140,141,143,144,146,147,149,150,152,153,155,156,158,159,161,162,164,165,167,168,169,170,171,172,173,174,175,176,178,179,180,181,182,183,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,202,204,206,210,211,212,213,214,215,222,224,226,228,230,232) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   DISCHARGE_QTR  THCIC_ID          PROVIDER_NAME FAC_TEACHING_IND  \
# 0        2010Q4       100  Austin State Hospital              NaN
# 1        2010Q4       100  Austin State Hospital              NaN
# 2        2010Q4       100  Austin State Hospital              NaN
# ...

# %%
Y2010 = pd.concat([Q1, Q2, Q3, Q4], sort = False)
Y2010.head()
# Out:
#   DISCHARGE_QTR  THCIC_ID          PROVIDER_NAME FAC_TEACHING_IND  \
# 0        2010Q1       100  Austin State Hospital              NaN
# 1        2010Q1       100  Austin State Hospital              NaN
# 2        2010Q1       100  Austin State Hospital              NaN
# 3        2010Q1       100  Austin State Hospital              NaN
# 4        2010Q1       100  Austin State Hospital              NaN
#
#   FAC_PSYCH_IND FAC_REHAB_IND FAC_ACUTE_CARE_IND FAC_SNF_IND  \
# 0             X           NaN                NaN         NaN
# 1             X           NaN                NaN         NaN
# 2             X           NaN                NaN         NaN
# 3             X           NaN                NaN         NaN
# 4             X           NaN                NaN         NaN
#
#   FAC_LONG_TERM_AC_IND FAC_OTHER_LTC_IND  ... HCFA_MDC APR_MDC  HCFA_DRG  \
# 0                  NaN               NaN  ...        1       1        93
# ...

# %%
Y2010.tail()
# Out:
#        DISCHARGE_QTR  THCIC_ID                  PROVIDER_NAME  \
# 741880        2010Q4    999999  Low Discharge Volume Hospital
# 741881        2010Q4    999999  Low Discharge Volume Hospital
# 741882        2010Q4    999999  Low Discharge Volume Hospital
# 741883        2010Q4    999999  Low Discharge Volume Hospital
# 741884        2010Q4    999999  Low Discharge Volume Hospital
#
#        FAC_TEACHING_IND FAC_PSYCH_IND FAC_REHAB_IND FAC_ACUTE_CARE_IND  \
# 741880              NaN           NaN           NaN                NaN
# 741881              NaN           NaN           NaN                NaN
# 741882              NaN           NaN           NaN                NaN
# 741883              NaN           NaN           NaN                NaN
# 741884              NaN           NaN           NaN                NaN
#
#        FAC_SNF_IND FAC_LONG_TERM_AC_IND FAC_OTHER_LTC_IND  ... HCFA_MDC  \
# 741880         NaN                  NaN               NaN  ...        2
# ...

# %%
Y2010.shape
# Out:
# (2978627, 255)

# %%
print(Q1.shape[0] + Q2.shape[0] + Q3.shape[0] + Q4.shape[0])
# Out:
# 2978627

# %%
start = time.time()
Y2010.to_csv('Base_10.csv')
end = time.time()
print(end - start)
# Out:
# 317.160546541214
