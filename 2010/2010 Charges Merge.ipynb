# %%
import pandas as pd
import numpy as np
import time

# %%
Q1 = pd.read_csv('2010Q1_Charges.csv', index_col = 0)
Q1.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (2,3,4,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\python38\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#       RECORD_ID REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE MODIFIER_1  \
# 0  120101891236          100             NaN                  NaN        NaN
# 1  120101891237          100             NaN                  NaN        NaN
# 2  120101891238          100             NaN                  NaN        NaN
# 3  120101891239          100             NaN                  NaN        NaN
# 4  120101891240          100             NaN                  NaN        NaN
#
# ...

# %%
Q2 = pd.read_csv('2010Q2_Charges.csv', index_col = 0)
Q2.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (2,3,4,5,6,10,12,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\python38\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#       RECORD_ID REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE MODIFIER_1  \
# 0  120102857683          270             NaN                  NaN        NaN
# 1  120102857683          300              HC                81025        NaN
# 2  120102857683          636              HC                J3010        NaN
# 3  120102857683          710             NaN                  NaN        NaN
# 4  120102857683          370             NaN                  NaN        NaN
#
# ...

# %%
Q3 = pd.read_csv('2010Q3_Charges.csv', index_col = 0)
Q3.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (2,3,4,5,6,10,12,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\python38\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#       RECORD_ID REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE MODIFIER_1  \
# 0  220102931516          250              HC                  NaN        NaN
# 1  220102931516          300              HC                81003        NaN
# 2  220102931516          320              HC                73562        NaN
# 3  220102931516          350              HC                71250        NaN
# 4  220102931516          450              HC                  NaN        NaN
#
# ...

# %%
Q4 = pd.read_csv('2010Q4_Charges.csv', index_col = 0)
Q4.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (3,4,5,6,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\python38\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#       RECORD_ID  REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE MODIFIER_1  \
# 0  320102990029         110.0             NaN                  NaN        NaN
# 1  320102990029         200.0             NaN                  NaN        NaN
# 2  320102990029         250.0             NaN                  NaN        NaN
# 3  320102990029         260.0             NaN                  NaN        NaN
# 4  320102990029         271.0             NaN                  NaN        NaN
#
# ...

# %%
Y2010 = pd.concat([Q1, Q2, Q3, Q4], sort = False)
Y2010.head()
# Out:
#       RECORD_ID REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE MODIFIER_1  \
# 0  120101891236          100             NaN                  NaN        NaN
# 1  120101891237          100             NaN                  NaN        NaN
# 2  120101891238          100             NaN                  NaN        NaN
# 3  120101891239          100             NaN                  NaN        NaN
# 4  120101891240          100             NaN                  NaN        NaN
#
#   MODIFIER_2  MODIFIER_3  MODIFIER_4 UNIT_MEASUREMENT_CODE UNITS_OF_SERVICE  \
# 0        NaN         NaN         NaN                    DA               26
# 1        NaN         NaN         NaN                    DA               51
# 2        NaN         NaN         NaN                    DA               43
# 3        NaN         NaN         NaN                    DA                8
# 4        NaN         NaN         NaN                    DA                4
#
#    UNIT_RATE CHRGS_LINE_ITEM CHRGS_NON_COV
# ...

# %%
Y2010.tail()
# Out:
#              RECORD_ID REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE  \
# 11344144  420103038682          420             NaN                  NaN
# 11344145  420103038682          424             NaN                  NaN
# 11344146  420103038682          430             NaN                  NaN
# 11344147  420103038682          434             NaN                  NaN
# 11344148  420103038682          460             NaN                  NaN
#
#          MODIFIER_1 MODIFIER_2  MODIFIER_3  MODIFIER_4 UNIT_MEASUREMENT_CODE  \
# 11344144        NaN        NaN         NaN         NaN                    UN
# 11344145        NaN        NaN         NaN         NaN                    UN
# 11344146        NaN        NaN         NaN         NaN                    UN
# 11344147        NaN        NaN         NaN         NaN                    UN
# 11344148        NaN        NaN         NaN         NaN                    UN
#
# ...

# %%
Y2010.shape
# Out:
# (45538200, 13)

# %%
print(Q1.shape[0] + Q2.shape[0] + Q3.shape[0] + Q4.shape[0])
# Out:
# 45538200

# %%
start = time.time()
Y2010.to_csv('Charges_10.csv')
end = time.time()
print(end - start)
# Out:
# 258.1729633808136
