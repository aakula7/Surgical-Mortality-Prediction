# %%
import pandas as pd
import numpy as np
import time

# %%
Q1 = pd.read_csv('2009Q1_Charges.csv', index_col = 0)
Q1.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (3,4,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\python38\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#       RECORD_ID  REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE MODIFIER_1  \
# 0  120080798822         124.0              HC                H2013        NaN
# 1  120080798822         124.0              HC                H2013        NaN
# 2  120090000001         100.0             NaN                  NaN        NaN
# 3  120090000002         100.0             NaN                  NaN        NaN
# 4  120090000003         100.0             NaN                  NaN        NaN
#
# ...

# %%
Q2 = pd.read_csv('2009Q2_Charges.csv', index_col = 0)
Q2.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (2,3,4,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\python38\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#       RECORD_ID REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE MODIFIER_1  \
# 0  120090799552          110             NaN                  NaN        NaN
# 1  120090799552          206             NaN                  NaN        NaN
# 2  120090799552          250             NaN                  NaN        NaN
# 3  120090799552          259             NaN                  NaN        NaN
# 4  120090799552          270             NaN                  NaN        NaN
#
# ...

# %%
Q3 = pd.read_csv('2009Q3_Charges.csv', index_col = 0)
Q3.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (2,3,4,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\python38\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#       RECORD_ID REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE MODIFIER_1  \
# 0  220090732643          100             NaN                  NaN        NaN
# 1  220090732644          100             NaN                  NaN        NaN
# 2  220090732645          100             NaN                  NaN        NaN
# 3  220090732646          100             NaN                  NaN        NaN
# 4  220090732647          100             NaN                  NaN        NaN
#
# ...

# %%
Q4 = pd.read_csv('2009Q4_Charges.csv', index_col = 0)
Q4.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (2,3,4,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\python38\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#       RECORD_ID REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE MODIFIER_1  \
# 0  320090761731         0100             NaN                  NaN        NaN
# 1  320090761732         0120             NaN                  NaN        NaN
# 2  320090761733         0120             NaN                  NaN        NaN
# 3  320090761734         0120             NaN                  NaN        NaN
# 4  320090761735         0120             NaN                  NaN        NaN
#
# ...

# %%
Y2009 = pd.concat([Q1, Q2, Q3, Q4], sort = False)
Y2009.head()
# Out:
#       RECORD_ID REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE MODIFIER_1  \
# 0  120080798822          124              HC                H2013        NaN
# 1  120080798822          124              HC                H2013        NaN
# 2  120090000001          100             NaN                  NaN        NaN
# 3  120090000002          100             NaN                  NaN        NaN
# 4  120090000003          100             NaN                  NaN        NaN
#
#   MODIFIER_2  MODIFIER_3  MODIFIER_4 UNIT_MEASUREMENT_CODE  UNITS_OF_SERVICE  \
# 0        NaN         NaN         NaN                    DA               2.0
# 1        NaN         NaN         NaN                    DA               9.0
# 2        NaN         NaN         NaN                    DA              16.0
# 3        NaN         NaN         NaN                    DA              16.0
# 4        NaN         NaN         NaN                    DA               1.0
#
# ...

# %%
Y2009.tail()
# Out:
#              RECORD_ID REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE  \
# 12311839  420095202381          424              HC                97001
# 12311840  420095202381          460              HC                94010
# 12311841  420095202381          460              HC                94760
# 12311842  420095202381          636              HC                J2405
# 12311843  420095202381          710             NaN                  NaN
#
#          MODIFIER_1 MODIFIER_2  MODIFIER_3  MODIFIER_4 UNIT_MEASUREMENT_CODE  \
# 12311839         GP        NaN         NaN         NaN                    UN
# 12311840        NaN        NaN         NaN         NaN                    UN
# 12311841        NaN        NaN         NaN         NaN                    UN
# 12311842        NaN        NaN         NaN         NaN                    UN
# 12311843        NaN        NaN         NaN         NaN                    UN
#
# ...

# %%
Y2009.shape
# Out:
# (46476080, 13)

# %%
print(Q1.shape[0] + Q2.shape[0] + Q3.shape[0] + Q4.shape[0])
# Out:
# 46476080

# %%
start = time.time()
Y2009.to_csv('Charges_09.csv')
end = time.time()
print(end - start)
# Out:
# 324.369083404541
