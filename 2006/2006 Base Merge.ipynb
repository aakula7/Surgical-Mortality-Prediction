# %%
import pandas as pd
import numpy as np
import time

# %%
Q1 = pd.read_csv('2006Q1_Base.csv', index_col = 0)
Q1.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (4,5,6,7,8,9,10,11,15,16,18,19,25,26,27,29,30,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,95,98,99,101,104,107,110,113,116,119,122,125,128,168,169,170,171,172,173,178,179,180,181,186,187,188,189,190,191,192,193,194,195,196,198,200,202,210,211,212,213,214,215,222,224,226,228,230,232,234) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   DISCHARGE_QTR  THCIC_ID          PROVIDER_NAME FAC_TEACHING_IND  \
# 0        2006Q1       100  Austin State Hospital              NaN
# 1        2006Q1       100  Austin State Hospital              NaN
# 2        2006Q1       100  Austin State Hospital              NaN
# 3        2006Q1       100  Austin State Hospital              NaN
# 4        2006Q1       100  Austin State Hospital              NaN
#
# ...

# %%
Q1.head(20)
# Out:
#    DISCHARGE_QTR  THCIC_ID          PROVIDER_NAME FAC_TEACHING_IND  \
# 0         2006Q1       100  Austin State Hospital              NaN
# 1         2006Q1       100  Austin State Hospital              NaN
# 2         2006Q1       100  Austin State Hospital              NaN
# 3         2006Q1       100  Austin State Hospital              NaN
# 4         2006Q1       100  Austin State Hospital              NaN
# 5         2006Q1       100  Austin State Hospital              NaN
# 6         2006Q1       100  Austin State Hospital              NaN
# 7         2006Q1       100  Austin State Hospital              NaN
# 8         2006Q1       100  Austin State Hospital              NaN
# 9         2006Q1       100  Austin State Hospital              NaN
# 10        2006Q1       100  Austin State Hospital              NaN
# 11        2006Q1       100  Austin State Hospital              NaN
# 12        2006Q1       100  Austin State Hospital              NaN
# ...

# %%
Q1.shape
# Out:
# (732873, 255)

# %%
Q2 = pd.read_csv('2006Q2_Base.csv', index_col = 0)
Q2.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (4,5,6,7,8,9,10,11,15,16,18,19,25,26,27,29,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,95,98,101,104,107,110,113,116,119,122,125,168,169,170,171,172,173,174,178,179,180,181,186,187,188,189,190,191,192,193,194,195,196,198,200,202,210,211,212,213,214,215,222,224,226,228,230,232,234) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   DISCHARGE_QTR  THCIC_ID          PROVIDER_NAME FAC_TEACHING_IND  \
# 0        2006Q2       100  Austin State Hospital              NaN
# 1        2006Q2       100  Austin State Hospital              NaN
# 2        2006Q2       100  Austin State Hospital              NaN
# 3        2006Q2       100  Austin State Hospital              NaN
# 4        2006Q2       100  Austin State Hospital              NaN
#
# ...

# %%
Q3 = pd.read_csv('2006Q3_Base.csv', index_col = 0)
Q3.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (4,5,6,7,8,9,10,11,15,16,18,19,25,26,27,29,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,95,98,101,104,107,110,113,116,119,168,169,170,171,172,173,174,175,176,177,178,179,180,181,186,187,188,189,190,191,192,193,194,195,196,198,200,202,204,206,210,211,212,213,222,224,226,228,230,232,234) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   DISCHARGE_QTR  THCIC_ID          PROVIDER_NAME FAC_TEACHING_IND  \
# 0        2006Q3       100  Austin State Hospital              NaN
# 1        2006Q3       100  Austin State Hospital              NaN
# 2        2006Q2       100  Austin State Hospital              NaN
# 3        2006Q3       100  Austin State Hospital              NaN
# 4        2006Q2       100  Austin State Hospital              NaN
#
# ...

# %%
Q4 = pd.read_csv('2006Q4_Base.csv', index_col = 0)
Q4.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (4,5,6,7,8,9,10,11,15,16,18,19,25,26,27,29,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,95,98,168,169,170,171,172,173,174,175,178,179,180,181,186,187,188,189,190,191,192,193,194,195,196,197,198,200,202,204,206,210,211,212,222,224,226,228,230,232,234,236,238) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   DISCHARGE_QTR  THCIC_ID          PROVIDER_NAME FAC_TEACHING_IND  \
# 0        2006Q4       100  Austin State Hospital              NaN
# 1        2006Q4       100  Austin State Hospital              NaN
# 2        2006Q4       100  Austin State Hospital              NaN
# 3        2006Q4       100  Austin State Hospital              NaN
# 4        2006Q4       100  Austin State Hospital              NaN
#
# ...

# %%
Y2006 = pd.concat([Q1, Q2, Q3, Q4], sort = False)
Y2006.head()
# Out:
#   DISCHARGE_QTR  THCIC_ID          PROVIDER_NAME FAC_TEACHING_IND  \
# 0        2006Q1       100  Austin State Hospital              NaN
# 1        2006Q1       100  Austin State Hospital              NaN
# 2        2006Q1       100  Austin State Hospital              NaN
# 3        2006Q1       100  Austin State Hospital              NaN
# 4        2006Q1       100  Austin State Hospital              NaN
#
#   FAC_PSYCH_IND FAC_REHAB_IND FAC_ACUTE_CARE_IND FAC_SNF_IND  \
# 0             X           NaN                NaN         NaN
# 1             X           NaN                NaN         NaN
# 2             X           NaN                NaN         NaN
# 3             X           NaN                NaN         NaN
# 4             X           NaN                NaN         NaN
#
#   FAC_LONG_TERM_AC_IND FAC_OTHER_LTC_IND  ... HCFA_MDC APR_MDC  HCFA_DRG  \
# 0                  NaN               NaN  ...       19      19       425
# ...

# %%
Y2006.tail()
# Out:
#        DISCHARGE_QTR  THCIC_ID                  PROVIDER_NAME  \
# 733364        2006Q4    999999  Low Discharge Volume Hospital
# 733365        2006Q4    999999  Low Discharge Volume Hospital
# 733366        2006Q4    999999  Low Discharge Volume Hospital
# 733367        2006Q4    999999  Low Discharge Volume Hospital
# 733368        2006Q4    999999  Low Discharge Volume Hospital
#
#        FAC_TEACHING_IND FAC_PSYCH_IND FAC_REHAB_IND FAC_ACUTE_CARE_IND  \
# 733364              NaN           NaN           NaN                NaN
# 733365              NaN           NaN           NaN                NaN
# 733366              NaN           NaN           NaN                NaN
# 733367              NaN           NaN           NaN                NaN
# 733368              NaN           NaN           NaN                NaN
#
#        FAC_SNF_IND FAC_LONG_TERM_AC_IND FAC_OTHER_LTC_IND  ... HCFA_MDC  \
# 733364         NaN                  NaN               NaN  ...        5
# ...

# %%
Y2006.shape
# Out:
# (2917188, 255)

# %%
print(Q1.shape[0] + Q2.shape[0] + Q3.shape[0] + Q4.shape[0])
# Out:
# 2917188

# %%
start = time.time()
Y2006.to_csv('Base_06.csv')
end = time.time()
print(end - start)
# Out:
# 345.4983105659485
