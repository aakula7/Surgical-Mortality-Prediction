# %%
import pandas as pd
import numpy as np
from collections import OrderedDict

# %%
# %time

df = pd.read_csv('Base_06.csv', index_col = 0)
# Out:
# Wall time: 0 ns
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (4,5,6,7,8,9,10,11,15,16,18,19,25,26,27,29,30,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,95,98,99,101,104,107,110,113,116,119,122,125,128,168,169,170,171,172,173,174,175,176,177,178,179,180,181,186,187,188,189,190,191,192,193,194,195,196,197,198,200,202,204,206,210,211,212,213,214,215,222,224,226,228,230,232,234,236,238) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\python38\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
df.head()
# Out:
#   DISCHARGE_QTR  THCIC_ID          PROVIDER_NAME FAC_TEACHING_IND  \
# 0        2006Q1       100  Austin State Hospital              NaN
# 1        2006Q1       100  Austin State Hospital              NaN
# 2        2006Q1       100  Austin State Hospital              NaN
# 3        2006Q1       100  Austin State Hospital              NaN
# 4        2006Q1       100  Austin State Hospital              NaN
#
#   FAC_PSYCH_IND FAC_REHAB_IND FAC_ACUTE_CARE_IND FAC_SNF_IND  \
# 0             X           NaN                NaN         NaN
# 1             X           NaN                NaN         NaN
# 2             X           NaN                NaN         NaN
# 3             X           NaN                NaN         NaN
# 4             X           NaN                NaN         NaN
#
#   FAC_LONG_TERM_AC_IND FAC_OTHER_LTC_IND  ... HCFA_MDC APR_MDC  HCFA_DRG  \
# 0                  NaN               NaN  ...       19      19       425
# ...

# %%
df.tail()
# Out:
#        DISCHARGE_QTR  THCIC_ID                  PROVIDER_NAME  \
# 733364        2006Q4    999999  Low Discharge Volume Hospital
# 733365        2006Q4    999999  Low Discharge Volume Hospital
# 733366        2006Q4    999999  Low Discharge Volume Hospital
# 733367        2006Q4    999999  Low Discharge Volume Hospital
# 733368        2006Q4    999999  Low Discharge Volume Hospital
#
#        FAC_TEACHING_IND FAC_PSYCH_IND FAC_REHAB_IND FAC_ACUTE_CARE_IND  \
# 733364              NaN           NaN           NaN                NaN
# 733365              NaN           NaN           NaN                NaN
# 733366              NaN           NaN           NaN                NaN
# 733367              NaN           NaN           NaN                NaN
# 733368              NaN           NaN           NaN                NaN
#
#        FAC_SNF_IND FAC_LONG_TERM_AC_IND FAC_OTHER_LTC_IND  ... HCFA_MDC  \
# 733364         NaN                  NaN               NaN  ...        5
# ...

# %%
df = df.drop(columns = ['PROVIDER_NAME'])
df.head()
# Out:
#   DISCHARGE_QTR  THCIC_ID FAC_TEACHING_IND FAC_PSYCH_IND FAC_REHAB_IND  \
# 0        2006Q1       100              NaN             X           NaN
# 1        2006Q1       100              NaN             X           NaN
# 2        2006Q1       100              NaN             X           NaN
# 3        2006Q1       100              NaN             X           NaN
# 4        2006Q1       100              NaN             X           NaN
#
#   FAC_ACUTE_CARE_IND FAC_SNF_IND FAC_LONG_TERM_AC_IND FAC_OTHER_LTC_IND  \
# 0                NaN         NaN                  NaN               NaN
# 1                NaN         NaN                  NaN               NaN
# 2                NaN         NaN                  NaN               NaN
# 3                NaN         NaN                  NaN               NaN
# 4                NaN         NaN                  NaN               NaN
#
#   FAC_PEDS_IND  ... HCFA_MDC  APR_MDC HCFA_DRG APR_DRG RISK_MORTALITY  \
# ...

# %%
df.shape
# Out:
# (2917188, 254)

# %%
print('Type of Principal Diag Code Column: ', df.PRINC_DIAG_CODE.dtype)
print('Type of Principal Surg Proc Code Column: ', df.PRINC_SURG_PROC_CODE.dtype)
print('Type of Principal ICD9 Code Column: ', df.PRINC_ICD9_CODE.dtype)
# Out:
# Type of Principal Diag Code Column:  object
# Type of Principal Surg Proc Code Column:  object
# Type of Principal ICD9 Code Column:  object

# %%
print('Number of Null Values in Principal Diag Code Column: ', df.PRINC_DIAG_CODE.isnull().sum())
print('Number of Null Values in Principal Surg Proc Code Column: ', df.PRINC_SURG_PROC_CODE.isnull().sum())
print('Number of Null Values in Principal ICD9 Code Column: ', df.PRINC_ICD9_CODE.isnull().sum())
# Out:
# Number of Null Values in Principal Diag Code Column:  868
# Number of Null Values in Principal Surg Proc Code Column:  1066316
# Number of Null Values in Principal ICD9 Code Column:  1066430

# %%
def changetype(elem):
    try:
        return int(elem)
    except:
        return 0
    
df.PRINC_DIAG_CODE = df['PRINC_DIAG_CODE'].map(lambda x: changetype(x))
df.PRINC_ICD9_CODE = df['PRINC_ICD9_CODE'].map(lambda x: changetype(x))
df.PRINC_SURG_PROC_CODE = df['PRINC_SURG_PROC_CODE'].map(lambda x: changetype(x))

# %%
print('Type of Principal Diag Code Column: ', df.PRINC_DIAG_CODE.dtype)
print('Type of Principal Surg Proc Code Column: ', df.PRINC_SURG_PROC_CODE.dtype)
print('Type of Principal ICD9 Code Column: ', df.PRINC_ICD9_CODE.dtype)
# Out:
# Type of Principal Diag Code Column:  int64
# Type of Principal Surg Proc Code Column:  int64
# Type of Principal ICD9 Code Column:  int64

# %%
print('Number of Null Values in Principal Diag Code Column: ', df.PRINC_DIAG_CODE.isnull().sum())
print('Number of Null Values in Principal Surg Proc Code Column: ', df.PRINC_SURG_PROC_CODE.isnull().sum())
print('Number of Null Values in Principal ICD9 Code Column: ', df.PRINC_ICD9_CODE.isnull().sum())
# Out:
# Number of Null Values in Principal Diag Code Column:  0
# Number of Null Values in Principal Surg Proc Code Column:  0
# Number of Null Values in Principal ICD9 Code Column:  0

# %%
proc_code = [362, 370, 387, 390, 391]

for x in range(3500, 4000):
    proc_code.append(x)
    
proc_code
# Out:
# [362,
#  370,
#  387,
#  390,
#  391,
#  3500,
#  3501,
#  3502,
#  3503,
#  3504,
#  3505,
#  3506,
#  3507,
#  3508,
#  3509,
#  3510,
#  3511,
#  3512,
#  3513,
#  3514,
#  3515,
#  3516,
#  3517,
#  3518,
#  3519,
#  3520,
#  3521,
#  3522,
#  3523,
#  3524,
#  3525,
#  3526,
#  3527,
#  3528,
#  3529,
#  3530,
#  3531,
#  3532,
#  3533,
#  3534,
#  3535,
#  3536,
#  3537,
#  3538,
#  3539,
#  3540,
#  3541,
#  3542,
#  3543,
#  3544,
#  3545,
#  3546,
#  3547,
#  3548,
#  3549,
#  3550,
#  3551,
#  3552,
#  3553,
#  3554,
#  3555,
#  3556,
#  3557,
#  3558,
#  3559,
#  3560,
#  3561,
#  3562,
#  3563,
#  3564,
#  3565,
#  3566,
#  3567,
#  3568,
#  3569,
#  3570,
#  3571,
#  3572,
#  3573,
#  3574,
#  3575,
#  3576,
#  3577,
#  3578,
#  3579,
#  3580,
#  3581,
#  3582,
#  3583,
#  3584,
#  3585,
#  3586,
#  3587,
#  3588,
#  3589,
#  3590,
#  3591,
#  3592,
#  3593,
#  3594,
#  3595,
#  3596,
#  3597,
#  3598,
#  3599,
#  3600,
#  3601,
#  3602,
#  3603,
#  3604,
#  3605,
# ...

# %%
surg_count = df['PRINC_SURG_PROC_CODE'].value_counts().to_dict()

for s in list(surg_count.keys()):
    if s not in proc_code:
        del surg_count[s]

surg_code_count = pd.DataFrame(list(surg_count.items()), columns = ['Surg_Code_1', 'Surg_Count_1'])
surg_code_count.head()
# Out:
#    Surg_Code_1  Surg_Count_1
# 0         3893         41575
# 1         3722         33980
# 2         3995         29301
# 3         3950         11717
# 4         3812          8199

# %%
surg_code_count.shape
# Out:
# (239, 2)

# %%
proc_count = df['PRINC_ICD9_CODE'].value_counts().to_dict()

for p in list(proc_count.keys()):
    if p not in proc_code:
        del proc_count[p]

ICD9_code_count = pd.DataFrame(list(proc_count.items()), columns = ['ICD9_Code_1', 'ICD9_Count_1'])
ICD9_code_count.head()
# Out:
#    ICD9_Code_1  ICD9_Count_1
# 0         3893         41252
# 1         3722         33911
# 2         3995         29186
# 3         3950         11610
# 4         3812          8178

# %%
ICD9_code_count.shape
# Out:
# (239, 2)

# %%
df = df[df['PRINC_ICD9_CODE'].isin(proc_code) | df['PRINC_SURG_PROC_CODE'].isin(proc_code)]
df.head()
# Out:
#      DISCHARGE_QTR  THCIC_ID FAC_TEACHING_IND FAC_PSYCH_IND FAC_REHAB_IND  \
# 1300        2006Q1       102                A           NaN           NaN
# 1308        2006Q1       102                A           NaN           NaN
# 1339        2006Q1       102                A           NaN           NaN
# 1341        2006Q1       102                A           NaN           NaN
# 1410        2006Q1       102                A           NaN           NaN
#
#      FAC_ACUTE_CARE_IND FAC_SNF_IND FAC_LONG_TERM_AC_IND FAC_OTHER_LTC_IND  \
# 1300                NaN         NaN                  NaN               NaN
# 1308                NaN         NaN                  NaN               NaN
# 1339                NaN         NaN                  NaN               NaN
# 1341                NaN         NaN                  NaN               NaN
# 1410                NaN         NaN                  NaN               NaN
#
# ...

# %%
surg_count = df['PRINC_SURG_PROC_CODE'].value_counts().to_dict()

for s in list(surg_count.keys()):
    if s not in proc_code:
        del surg_count[s]

surg_code_count_2 = pd.DataFrame(list(surg_count.items()), columns = ['Surg_Code_2', 'Surg_Count_2'])
surg_code_count_2.head()
# Out:
#    Surg_Code_2  Surg_Count_2
# 0         3722         23175
# 1         3772          5848
# 2         3613          5625
# 3         3612          5489
# 4         3794          4900

# %%
surg_code_count_2.shape
# Out:
# (180, 2)

# %%
proc_count = df['PRINC_ICD9_CODE'].value_counts().to_dict()

for p in list(proc_count.keys()):
    if p not in proc_code:
        del proc_count[p]

ICD9_code_count_2 = pd.DataFrame(list(proc_count.items()), columns = ['ICD9_Code_2', 'ICD9_Count_2'])
ICD9_code_count_2.head()
# Out:
#    ICD9_Code_2  ICD9_Count_2
# 0         3722         23127
# 1         3772          5744
# 2         3613          5534
# 3         3612          5394
# 4         3794          4883

# %%
ICD9_code_count_2.shape
# Out:
# (180, 2)

# %%
diag_code = [390, 393, 412]

for x in range(3910, 3981):
    diag_code.append(x)

for x in range(4110, 4290):
    diag_code.append(x)

for x in range(39890, 40292):
    diag_code.append(x)

for x in range(40400, 40494):
    diag_code.append(x)    

for x in range(41000, 42843):
    diag_code.append(x)
    
diag_code
# Out:
# [390,
#  393,
#  412,
#  3910,
#  3911,
#  3912,
#  3913,
#  3914,
#  3915,
#  3916,
#  3917,
#  3918,
#  3919,
#  3920,
#  3921,
#  3922,
#  3923,
#  3924,
#  3925,
#  3926,
#  3927,
#  3928,
#  3929,
#  3930,
#  3931,
#  3932,
#  3933,
#  3934,
#  3935,
#  3936,
#  3937,
#  3938,
#  3939,
#  3940,
#  3941,
#  3942,
#  3943,
#  3944,
#  3945,
#  3946,
#  3947,
#  3948,
#  3949,
#  3950,
#  3951,
#  3952,
#  3953,
#  3954,
#  3955,
#  3956,
#  3957,
#  3958,
#  3959,
#  3960,
#  3961,
#  3962,
#  3963,
#  3964,
#  3965,
#  3966,
#  3967,
#  3968,
#  3969,
#  3970,
#  3971,
#  3972,
#  3973,
#  3974,
#  3975,
#  3976,
#  3977,
#  3978,
#  3979,
#  3980,
#  4110,
#  4111,
#  4112,
#  4113,
#  4114,
#  4115,
#  4116,
#  4117,
#  4118,
#  4119,
#  4120,
#  4121,
#  4122,
#  4123,
#  4124,
#  4125,
#  4126,
#  4127,
#  4128,
#  4129,
#  4130,
#  4131,
#  4132,
#  4133,
#  4134,
#  4135,
#  4136,
#  4137,
#  4138,
#  4139,
#  4140,
#  4141,
#  4142,
#  4143,
#  4144,
#  4145,
#  4146,
# ...

# %%
diag_count = df['PRINC_DIAG_CODE'].value_counts().to_dict()

for d in list(diag_count.keys()):
    if d not in diag_code:
        del diag_count[d]

diag_code_count = pd.DataFrame(list(diag_count.items()), columns = ['Diag_Code_1', 'Diag_Count_1'])
diag_code_count.head()
# Out:
#    Diag_Code_1  Diag_Count_1
# 0        41401         26903
# 1         4280         11167
# 2        41071          8539
# 3        42781          4912
# 4        42731          4005

# %%
diag_code_count.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ead71ff83d75> in <module>
# ----> 1 diag_code_count.shape
#
# NameError: name 'diag_code_count' is not defined

# %%
df = df[df['PRINC_DIAG_CODE'].isin(diag_code)]
df.head()
# Out:
#      DISCHARGE_QTR  THCIC_ID FAC_TEACHING_IND FAC_PSYCH_IND FAC_REHAB_IND  \
# 1765        2006Q1       102                A           NaN           NaN
# 1770        2006Q1       102                A           NaN           NaN
# 2329        2006Q1       102                A           NaN           NaN
# 2330        2006Q1       102                A           NaN           NaN
# 2331        2006Q1       102                A           NaN           NaN
#
#      FAC_ACUTE_CARE_IND FAC_SNF_IND FAC_LONG_TERM_AC_IND FAC_OTHER_LTC_IND  \
# 1765                NaN         NaN                  NaN               NaN
# 1770                NaN         NaN                  NaN               NaN
# 2329                NaN         NaN                  NaN               NaN
# 2330                NaN         NaN                  NaN               NaN
# 2331                NaN         NaN                  NaN               NaN
#
# ...

# %%
diag_count_check = df['PRINC_DIAG_CODE'].value_counts().to_dict()

for d in list(diag_count.keys()):
    if d not in diag_code:
        del diag_count[d]

diag_code_count_2 = pd.DataFrame(list(diag_count.items()), columns = ['Diag_Code_2', 'Diag_Count_2'])
diag_code_count_2.head()
# Out:
#    Diag_Code_2  Diag_Count_2
# 0        41401         26903
# 1         4280         11167
# 2        41071          8539
# 3        42781          4912
# 4        42731          4005

# %%
diag_code_count_2.shape
# Out:
# (160, 2)

# %%
df.shape
# Out:
# (84393, 254)

# %%
df.head()
# Out:
#      DISCHARGE_QTR  THCIC_ID FAC_TEACHING_IND FAC_PSYCH_IND FAC_REHAB_IND  \
# 1765        2006Q1       102                A           NaN           NaN
# 1770        2006Q1       102                A           NaN           NaN
# 2329        2006Q1       102                A           NaN           NaN
# 2330        2006Q1       102                A           NaN           NaN
# 2331        2006Q1       102                A           NaN           NaN
#
#      FAC_ACUTE_CARE_IND FAC_SNF_IND FAC_LONG_TERM_AC_IND FAC_OTHER_LTC_IND  \
# 1765                NaN         NaN                  NaN               NaN
# 1770                NaN         NaN                  NaN               NaN
# 2329                NaN         NaN                  NaN               NaN
# 2330                NaN         NaN                  NaN               NaN
# 2331                NaN         NaN                  NaN               NaN
#
# ...

# %%
df = df.reset_index(drop = True)
df.head()
# Out:
#   DISCHARGE_QTR  THCIC_ID FAC_TEACHING_IND FAC_PSYCH_IND FAC_REHAB_IND  \
# 0        2006Q1       102                A           NaN           NaN
# 1        2006Q1       102                A           NaN           NaN
# 2        2006Q1       102                A           NaN           NaN
# 3        2006Q1       102                A           NaN           NaN
# 4        2006Q1       102                A           NaN           NaN
#
#   FAC_ACUTE_CARE_IND FAC_SNF_IND FAC_LONG_TERM_AC_IND FAC_OTHER_LTC_IND  \
# 0                NaN         NaN                  NaN               NaN
# 1                NaN         NaN                  NaN               NaN
# 2                NaN         NaN                  NaN               NaN
# 3                NaN         NaN                  NaN               NaN
# 4                NaN         NaN                  NaN               NaN
#
#   FAC_PEDS_IND  ... HCFA_MDC  APR_MDC HCFA_DRG APR_DRG RISK_MORTALITY  \
# ...

# %%
df.to_csv('Base_06_Subset.csv')
