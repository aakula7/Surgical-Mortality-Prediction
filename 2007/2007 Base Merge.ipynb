# %%
import pandas as pd
import numpy as np
import time

# %%
Q1 = pd.read_csv('2007Q1_Base.csv', index_col = 0)
Q1.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (4,5,6,7,8,9,10,11,15,16,18,19,25,26,27,29,67,68,73,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,95,98,101,104,168,169,170,171,172,173,178,179,180,181,182,186,187,188,189,190,191,192,193,194,195,196,197,198,200,202,204,206,208,210,211,212,213,222,224,226,228,230,232,234,236) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   DISCHARGE_QTR  THCIC_ID          PROVIDER_NAME FAC_TEACHING_IND  \
# 0        2006Q4       100  Austin State Hospital              NaN
# 1        2007Q1       100  Austin State Hospital              NaN
# 2        2007Q1       100  Austin State Hospital              NaN
# 3        2007Q1       100  Austin State Hospital              NaN
# 4        2007Q1       100  Austin State Hospital              NaN
#
#   FAC_PSYCH_IND FAC_REHAB_IND FAC_ACUTE_CARE_IND FAC_SNF_IND  \
# ...

# %%
Q2 = pd.read_csv('2007Q2_Base.csv', index_col = 0)
Q2.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (4,5,6,7,8,9,10,11,15,16,18,19,25,26,27,29,67,68,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,95,98,101,104,107,110,113,116,119,122,125,128,131,134,168,169,170,171,172,173,174,178,179,180,181,182,186,187,188,189,190,191,192,193,194,195,196,198,200,202,204,206,208,210,211,212,213,222,224,226,228,230,232,234) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   DISCHARGE_QTR  THCIC_ID          PROVIDER_NAME FAC_TEACHING_IND  \
# 0        2007Q2       100  Austin State Hospital              NaN
# 1        2007Q2       100  Austin State Hospital              NaN
# 2        2007Q2       100  Austin State Hospital              NaN
# 3        2007Q2       100  Austin State Hospital              NaN
# 4        2007Q2       100  Austin State Hospital              NaN
#
# ...

# %%
Q3 = pd.read_csv('2007Q3_Base.csv', index_col = 0)
Q3.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (4,5,6,7,8,9,10,11,15,16,18,19,26,27,29,30,67,68,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,95,98,101,104,107,110,113,116,119,122,168,169,170,171,172,173,174,178,179,180,181,182,186,187,188,189,190,191,192,193,194,195,196,198,200,202,204,206,210,211,212,213,222,224,226,228,230,232) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   DISCHARGE_QTR  THCIC_ID          PROVIDER_NAME FAC_TEACHING_IND  \
# 0        2007Q3       100  Austin State Hospital              NaN
# 1        2007Q3       100  Austin State Hospital              NaN
# 2        2007Q3       100  Austin State Hospital              NaN
# 3        2007Q3       100  Austin State Hospital              NaN
# 4        2007Q3       100  Austin State Hospital              NaN
#
# ...

# %%
Q4 = pd.read_csv('2007Q4_Base.csv', index_col = 0)
Q4.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (4,5,6,7,8,9,10,11,15,16,18,19,25,26,27,29,30,67,68,72,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,95,98,101,104,107,110,168,169,170,171,172,173,174,175,176,178,179,180,181,182,186,187,188,189,190,191,192,193,194,195,196,198,200,202,204,206,208,210,211,212,213,222,224,226,228,230,232) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   DISCHARGE_QTR  THCIC_ID          PROVIDER_NAME FAC_TEACHING_IND  \
# 0        2007Q4       100  Austin State Hospital              NaN
# 1        2007Q4       100  Austin State Hospital              NaN
# 2        2007Q4       100  Austin State Hospital              NaN
# 3        2007Q4       100  Austin State Hospital              NaN
# 4        2007Q4       100  Austin State Hospital              NaN
#
# ...

# %%
Y2007 = pd.concat([Q1, Q2, Q3, Q4], sort = False)
Y2007.head()
# Out:
#   DISCHARGE_QTR  THCIC_ID          PROVIDER_NAME FAC_TEACHING_IND  \
# 0        2006Q4       100  Austin State Hospital              NaN
# 1        2007Q1       100  Austin State Hospital              NaN
# 2        2007Q1       100  Austin State Hospital              NaN
# 3        2007Q1       100  Austin State Hospital              NaN
# 4        2007Q1       100  Austin State Hospital              NaN
#
#   FAC_PSYCH_IND FAC_REHAB_IND FAC_ACUTE_CARE_IND FAC_SNF_IND  \
# 0             X           NaN                NaN         NaN
# 1             X           NaN                NaN         NaN
# 2             X           NaN                NaN         NaN
# 3             X           NaN                NaN         NaN
# 4             X           NaN                NaN         NaN
#
#   FAC_LONG_TERM_AC_IND FAC_OTHER_LTC_IND  ... HCFA_MDC APR_MDC  HCFA_DRG  \
# 0                  NaN               NaN  ...       19      19       425
# ...

# %%
Y2007.tail()
# Out:
#        DISCHARGE_QTR  THCIC_ID                  PROVIDER_NAME  \
# 734425        2007Q4    999999  Low Discharge Volume Hospital
# 734426        2007Q4    999999  Low Discharge Volume Hospital
# 734427        2007Q4    999999  Low Discharge Volume Hospital
# 734428        2007Q4    999999  Low Discharge Volume Hospital
# 734429        2007Q4    999999  Low Discharge Volume Hospital
#
#        FAC_TEACHING_IND FAC_PSYCH_IND FAC_REHAB_IND FAC_ACUTE_CARE_IND  \
# 734425              NaN           NaN           NaN                NaN
# 734426              NaN           NaN           NaN                NaN
# 734427              NaN           NaN           NaN                NaN
# 734428              NaN           NaN           NaN                NaN
# 734429              NaN           NaN           NaN                NaN
#
#        FAC_SNF_IND FAC_LONG_TERM_AC_IND FAC_OTHER_LTC_IND  ... HCFA_MDC  \
# 734425         NaN                  NaN               NaN  ...       18
# ...

# %%
Y2007.shape
# Out:
# (2937770, 255)

# %%
print(Q1.shape[0] + Q2.shape[0] + Q3.shape[0] + Q4.shape[0])
# Out:
# 2937770

# %%
start = time.time()
Y2007.to_csv('Base_07.csv')
end = time.time()
print(end - start)
# Out:
# 358.0341954231262
