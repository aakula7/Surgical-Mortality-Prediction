# %%
import pandas as pd
import numpy as np
import time

# %%
Q1 = pd.read_csv('2007Q1_Charges.csv', index_col = 0)
Q1.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (3,4,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\python38\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#       RECORD_ID  REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE MODIFIER_1  \
# 0  120070000001         100.0             NaN                  NaN        NaN
# 1  120070000002         100.0             NaN                  NaN        NaN
# 2  120070000003         100.0             NaN                  NaN        NaN
# 3  120070000004         100.0             NaN                  NaN        NaN
# 4  120070000005         100.0             NaN                  NaN        NaN
#
# ...

# %%
Q2 = pd.read_csv('2007Q2_Charges.csv', index_col = 0)
Q2.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (3,4,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\python38\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#       RECORD_ID  REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE MODIFIER_1  \
# 0  120070785219         122.0             NaN                  NaN        NaN
# 1  120070785219         250.0             NaN                  NaN        NaN
# 2  120070785219         258.0             NaN                  NaN        NaN
# 3  120070785219         270.0             NaN                  NaN        NaN
# 4  120070785219         272.0             NaN                  NaN        NaN
#
# ...

# %%
Q3 = pd.read_csv('2007Q3_Charges.csv', index_col = 0)
Q3.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (2,3,4,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\python38\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#       RECORD_ID REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE MODIFIER_1  \
# 0  220070787218          110             NaN                  NaN        NaN
# 1  220070787218          250             NaN                  NaN        NaN
# 2  220070787218          271             NaN                  NaN        NaN
# 3  220070787218          272             NaN                  NaN        NaN
# 4  220070787218          300             NaN                  NaN        NaN
#
# ...

# %%
Q4 = pd.read_csv('2007Q4_Charges.csv', index_col = 0)
Q4.head()
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (3,4,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\python38\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#       RECORD_ID  REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE MODIFIER_1  \
# 0  320071572352         110.0             NaN                  NaN        NaN
# 1  320071572352         250.0             NaN                  NaN        NaN
# 2  320071572352         260.0             NaN                  NaN        NaN
# 3  320071572352         271.0             NaN                  NaN        NaN
# 4  320071572352         272.0             NaN                  NaN        NaN
#
# ...

# %%
Y2007 = pd.concat([Q1, Q2, Q3, Q4], sort = False)
Y2007.head()
# Out:
#       RECORD_ID REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE MODIFIER_1  \
# 0  120070000001          100             NaN                  NaN        NaN
# 1  120070000002          100             NaN                  NaN        NaN
# 2  120070000003          100             NaN                  NaN        NaN
# 3  120070000004          100             NaN                  NaN        NaN
# 4  120070000005          100             NaN                  NaN        NaN
#
#   MODIFIER_2  MODIFIER_3  MODIFIER_4 UNIT_MEASUREMENT_CODE  UNITS_OF_SERVICE  \
# 0        NaN         NaN         NaN                    DA              31.0
# 1        NaN         NaN         NaN                    DA               3.0
# 2        NaN         NaN         NaN                    DA              46.0
# 3        NaN         NaN         NaN                    DA               8.0
# 4        NaN         NaN         NaN                    DA              44.0
#
# ...

# %%
Y2007.tail()
# Out:
#              RECORD_ID REVENUE_CODE HCPCS_QUALIFIER HCPCS_PROCEDURE_CODE  \
# 11241561  420070800113          279             NaN                  NaN
# 11241562  420070800113          301             NaN                  NaN
# 11241563  420070800113          302             NaN                  NaN
# 11241564  420070800113          305             NaN                  NaN
# 11241565  420070800113          410             NaN                  NaN
#
#          MODIFIER_1 MODIFIER_2  MODIFIER_3  MODIFIER_4 UNIT_MEASUREMENT_CODE  \
# 11241561        NaN        NaN         NaN         NaN                    UN
# 11241562        NaN        NaN         NaN         NaN                    UN
# 11241563        NaN        NaN         NaN         NaN                    UN
# 11241564        NaN        NaN         NaN         NaN                    UN
# 11241565        NaN        NaN         NaN         NaN                    UN
#
# ...

# %%
Y2007.shape
# Out:
# (45345871, 13)

# %%
print(Q1.shape[0] + Q2.shape[0] + Q3.shape[0] + Q4.shape[0])
# Out:
# 45345871

# %%
start = time.time()
Y2007.to_csv('Charges_07.csv')
end = time.time()
print(end - start)
# Out:
# 368.633535861969
